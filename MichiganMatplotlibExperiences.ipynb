# %%
# %matplotlib notebook  #very important to show the graphs
import matplotlib.pyplot as plt
import numpy as np
# Out:
# UsageError: unrecognized arguments: #very important to show the graphs

# %%
plt.figure()
plt.subplot(1,2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sample_data = np.array([1,3,4,5,7])
plt.plot(sample_data,'-o')

# %%
sample_data2 = sample_data*2
plt.subplot(1,2,2)
plt.plot(sample_data2,'-o')

# %%
plt.subplot(1,2,1)
plt.plot(sample_data2,'-x')
